# %%
import datetime
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd

# Define the file path
file_path = 'DataSolarlabHVL.dat' 


# Initialize empty lists to store data
dates_and_times = []
radiation = []
i=0

# Read data from the file
try:
    with open(file_path, 'r') as file:
        Lines = file.readlines()[4:]
        
        for line in Lines:
            parts = line.strip().split(",")
            date_time_str, RN_str, Volts_str,Ptemp_str, mV_str = parts
            
            date_time = datetime.datetime.strptime(date_time_str, "%Y-%m-%d %H:%M:%S")
            
            if "NAN" in mV_str:
                mV_str=float('nan')
                
            else:
                mV_str=float(mV_str)
                
            radiation.append(mV_str)                   
            
            #date_time = datetime.datetime.strptime(time_str, "%Y-%m-%d %H:%M:%S")
            #dates_and_times.append(date_time)
            
        
except FileNotFoundError:
    print(f"Error: File '{file_path}' not found.")
    exit(1)
except (ValueError, IndexError):
    print(f"Error: Invalid data format in '{file_path}'.")
    exit(1)
# Out:
# Error: Invalid data format in 'DataSolarlabHVL.dat'.

# %%
time_str
# Out:
# '"2022-07-27 19:10:00"'

# %%
Lines
# Out:
# ['"2022-07-27 19:10:00",0,0,16.92,7.933\n',
#  '"2022-07-27 19:12:00",1,0,16.98,8.1\n',
#  '"2022-07-27 19:14:00",2,0,17.02,8.37\n',
#  '"2022-07-27 19:16:00",3,0,17.06,8.59\n',
#  '"2022-07-27 19:18:00",4,0,17.14,9.33\n',
#  '"2022-07-27 19:20:00",5,0,17.16,9.32\n',
#  '"2022-07-27 19:22:00",6,0,17.23,8.78\n',
#  '"2022-07-27 19:24:00",7,0,17.28,8.25\n',
#  '"2022-07-27 19:26:00",8,0,17.33,8.21\n',
#  '"2022-07-27 19:28:00",9,0,17.36,8.78\n',
#  '"2022-07-27 19:30:00",10,0,17.39,8.25\n',
#  '"2022-07-27 19:32:00",11,0,17.44,7.74\n',
#  '"2022-07-27 19:34:00",12,0,17.48,7.526\n',
#  '"2022-07-27 19:36:00",13,0,17.52,7.008\n',
#  '"2022-07-27 19:38:00",14,0,17.55,6.841\n',
#  '"2022-07-27 19:40:00",15,0,17.57,6.558\n',
#  '"2022-07-27 19:42:00",16,0,17.6,5.993\n',
#  '"2022-07-27 19:44:00",17,0,17.61,5.549\n',
#  '"2022-07-27 19:46:00",18,0,17.63,5.078\n',
#  '"2022-07-27 19:48:00",19,0,17.66,4.636\n',
#  '"2022-07-27 19:50:00",20,0,17.69,4.339\n',
# ...

# %%
float(mV_str)
# Out:
# 23.05

# %%
float(mV_str)
# Out:
# 23.05

# %%
y=float(mV_str)

# %%
y
# Out:
# 23.05

# %%
mV_str
# Out:
# '"NAN"'

# %%
time_str
# Out:
# '"2023-06-06 11:42:00"'

# %%
line
# Out:
# ['"2022-07-27 19:10:00",0,0,16.92,7.933\n',
#  '"2022-07-27 19:12:00",1,0,16.98,8.1\n',
#  '"2022-07-27 19:14:00",2,0,17.02,8.37\n',
#  '"2022-07-27 19:16:00",3,0,17.06,8.59\n',
#  '"2022-07-27 19:18:00",4,0,17.14,9.33\n',
#  '"2022-07-27 19:20:00",5,0,17.16,9.32\n',
#  '"2022-07-27 19:22:00",6,0,17.23,8.78\n',
#  '"2022-07-27 19:24:00",7,0,17.28,8.25\n',
#  '"2022-07-27 19:26:00",8,0,17.33,8.21\n',
#  '"2022-07-27 19:28:00",9,0,17.36,8.78\n',
#  '"2022-07-27 19:30:00",10,0,17.39,8.25\n',
#  '"2022-07-27 19:32:00",11,0,17.44,7.74\n',
#  '"2022-07-27 19:34:00",12,0,17.48,7.526\n',
#  '"2022-07-27 19:36:00",13,0,17.52,7.008\n',
#  '"2022-07-27 19:38:00",14,0,17.55,6.841\n',
#  '"2022-07-27 19:40:00",15,0,17.57,6.558\n',
#  '"2022-07-27 19:42:00",16,0,17.6,5.993\n',
#  '"2022-07-27 19:44:00",17,0,17.61,5.549\n',
#  '"2022-07-27 19:46:00",18,0,17.63,5.078\n',
#  '"2022-07-27 19:48:00",19,0,17.66,4.636\n',
#  '"2022-07-27 19:50:00",20,0,17.69,4.339\n',
# ...
